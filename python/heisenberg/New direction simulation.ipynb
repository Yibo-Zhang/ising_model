# %%
from New_direction_model import *

# %%
new_direction_model_1 = New_direction_model(N=3,step=1000,label='randmom:1')
new_direction_model_1.simulation()

new_direction_model_2 = New_direction_model(N=3,step=1000,label='randmom:2')
new_direction_model_2.simulation()

new_direction_model_3 = New_direction_model(N=3,step=1000,label='randmom:3')
new_direction_model_3.simulation()

new_direction_model_4 = New_direction_model(N=3,step=1000,label='randmom:4')
new_direction_model_4.simulation()
# Out:
# 已完成第0步模拟
# 已完成第300步模拟
# 已完成第600步模拟
# 已完成第900步模拟
# totally cost 0.7539050579071045
#
# 已完成第0步模拟
# 已完成第300步模拟
# 已完成第600步模拟
# 已完成第900步模拟
# totally cost 0.7127101421356201
#
# 已完成第0步模拟
# 已完成第300步模拟
# 已完成第600步模拟
# 已完成第900步模拟
# totally cost 0.7280797958374023
#
# 已完成第0步模拟
# 已完成第300步模拟
# 已完成第600步模拟
# 已完成第900步模拟
# totally cost 0.7312030792236328

# %%
from up_down_model import *

# %%
up_down_model_1 = Up_down_flip_model(N=3,step=1000,label='randmom:1')
up_down_model_1.simulation()
up_down_model_2 = Up_down_flip_model(N=3,step=1000,label='randmom:2')
up_down_model_2.simulation()
up_down_model_3 = Up_down_flip_model(N=3,step=1000,label='randmom:3')
up_down_model_3.simulation()
up_down_model_4 = Up_down_flip_model(N=3,step=1000,label='randmom:4')
up_down_model_4.simulation()
# Out:
# 已完成第0步模拟
# 已完成第300步模拟
# 已完成第600步模拟
# 已完成第900步模拟
# totally cost 0.7404882907867432
# 已完成第0步模拟
# 已完成第300步模拟
# 已完成第600步模拟
# 已完成第900步模拟
# totally cost 0.7327961921691895
# 已完成第0步模拟
# 已完成第300步模拟
# 已完成第600步模拟
# 已完成第900步模拟
# totally cost 0.7320089340209961
# 已完成第0步模拟
# 已完成第300步模拟
# 已完成第600步模拟
# 已完成第900步模拟
# totally cost 0.7275300025939941

# %%
up_down_model_4.plot_spin_z()

# %%
new_direction_model_4.plot_spin_z()

# %%
up_down_model_4.lowest_energy
# Out:
# array(-6.32748641)

# %%
new_direction_model_3.lowest_energy
# Out:
# -6.18471699379912
