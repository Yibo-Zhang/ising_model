# %%
import numpy as np
import matplotlib.pyplot as plt
import torch 
from torch import nn
from torch.utils.data import TensorDataset,Dataset,DataLoader,random_split
import datetime
import pandas as pd

# %% [markdown]
# # prepare data

# %%
with open('config.npy', 'rb') as f:
    config = np.load(f)
with open('J.npy', 'rb') as f:
    J = np.load(f)
with open('energy.npy', 'rb') as f:
    # energy 都是负的，在这里取 正值
    energy = -np.load(f)

# %%
data = TensorDataset(torch.tensor(J).float(),torch.tensor(energy).reshape(len(energy),1).float())

n_train = int(len(data)*0.8)
n_valid = len(data) - n_train
ds_train,ds_valid = random_split(data,[n_train,n_valid])

dl_train,dl_valid = DataLoader(ds_train,batch_size = 8),DataLoader(ds_valid,batch_size = 8)

# %%
for features,labels in dl_train:
    print(features.shape)
    print(labels.shape)
    break
# Out:
# torch.Size([8, 32])
# torch.Size([8, 1])

# %% [markdown]
# # prepare model

# %%
class Net(nn.Module): 
    def __init__(self):
        super(Net, self).__init__()
        self.linear1 = nn.Linear(32,16)
        self.lrelu1 = nn.LeakyReLU()
        self.linear2 = nn.Linear(16,1)
        self.lrelu2 = nn.LeakyReLU()
        
    def forward(self,x):
        x = self.linear1(x)
#         y = self.lrelu1(x)
        x = self.linear2(x)
        y = self.lrelu2(x)
        return y
        
model = Net()

# %%
from torchkeras import summary
summary(model,input_shape= (1000,32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1             [-1, 1000, 16]             528
#             Linear-2              [-1, 1000, 1]              17
#          LeakyReLU-3              [-1, 1000, 1]               0
# ================================================================
# Total params: 545
# Trainable params: 545
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.122070
# Forward/backward pass size (MB): 0.137329
# Params size (MB): 0.002079
# Estimated Total Size (MB): 0.261478
# ----------------------------------------------------------------

# %%
model.optimizer = torch.optim.SGD(model.parameters(),lr = 0.01)
model.loss_func = torch.nn.MSELoss()
model.metric_func = lambda y_pred,y_true: torch.mean(1-torch.abs(y_true-y_pred))
model.metric_name = "auc"

# %%
def train_step(model,features,labels):
    
    # 训练模式，dropout层发生作用
    model.train()
    
    # 梯度清零
    model.optimizer.zero_grad()
    
    # 正向传播求损失
    predictions = model(features)
    loss = model.loss_func(predictions,labels)
    metric = model.metric_func(predictions,labels)

    # 反向传播求梯度
    loss.backward()
    model.optimizer.step()

    return loss.item(),metric.item()

def valid_step(model,features,labels):
    
    # 预测模式，dropout层不发生作用
    model.eval()
    # 关闭梯度计算
    with torch.no_grad():
        predictions = model(features)
        loss = model.loss_func(predictions,labels)
        metric = model.metric_func(predictions,labels)
    
    return loss.item(), metric.item()


# 测试train_step效果
features,labels = next(iter(dl_train))
labels = labels.reshape(8,1)
train_step(model,features,labels)
# Out:
# (155.8196258544922, -11.406691551208496)

# %%
labels.reshape(8,1).shape
# Out:
# torch.Size([8, 1])

# %%
def train_model(model,epochs,dl_train,dl_valid,log_step_freq):

    metric_name = model.metric_name
    print("Start Training...")
    nowtime = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
    print("=========="*8 + "%s"%nowtime)
    df = pd.DataFrame([], columns=['EPOCH','loss','auc','val_loss','val_auc'])
    for epoch in range(1,epochs+1):  

        # 1，训练循环-------------------------------------------------
        loss_sum = 0.0
        metric_sum = 0.0
        step = 1

        for step, (features,labels) in enumerate(dl_train, 1):

            loss,metric = train_step(model,features,labels)

            # 打印batch级别日志
            loss_sum += loss
            metric_sum += metric
            if step%log_step_freq == 0:   
                print(("[step = %d] loss: %.3f, "+metric_name+": %.3f") %
                      (step, loss_sum/step, metric_sum/step))

        # 2，验证循环-------------------------------------------------
        val_loss_sum = 0.0
        val_metric_sum = 0.0
        val_step = 1

        for val_step, (features,labels) in enumerate(dl_valid, 1):

            val_loss,val_metric = valid_step(model,features,labels)

            val_loss_sum += val_loss
            val_metric_sum += val_metric

        # 3，记录日志-------------------------------------------------
        info = (epoch, loss_sum/step, metric_sum/step, 
                val_loss_sum/val_step, val_metric_sum/val_step)
        df = df.append(pd.DataFrame([info], columns=['EPOCH','loss','auc','val_loss','val_auc']),ignore_index=True)
        # 打印epoch级别日志
        print(("\nEPOCH = %d, loss = %.3f,"+ metric_name + \
              "  = %.3f, val_loss = %.3f, "+"val_"+ metric_name+" = %.3f") 
              # %info)
        nowtime = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        print("\n"+"=========="*8 + "%s"%nowtime)

    print('Finished Training...')
    
    return df

# %%
epochs = 100

history = train_model(model,epochs,dl_train,dl_valid,log_step_freq = 50)
# Out:
# Start Training...
# ================================================================================2021-10-06 10:18:37
# [step = 50] loss: 28.217, auc: -2.552
# [step = 100] loss: 15.207, auc: -1.374
#
# EPOCH = 1, loss = 15.207,auc  = -1.374, val_loss = 1.538, val_auc = 0.062
#
# ================================================================================2021-10-06 10:18:37
# [step = 50] loss: 2.386, auc: -0.230
# [step = 100] loss: 2.275, auc: -0.208
#
# EPOCH = 2, loss = 2.275,auc  = -0.208, val_loss = 1.523, val_auc = 0.068
#
# ================================================================================2021-10-06 10:18:37
# [step = 50] loss: 2.368, auc: -0.226
# [step = 100] loss: 2.257, auc: -0.204
#
# EPOCH = 3, loss = 2.257,auc  = -0.204, val_loss = 1.511, val_auc = 0.073
#
# ================================================================================2021-10-06 10:18:37
# [step = 50] loss: 2.353, auc: -0.222
# [step = 100] loss: 2.242, auc: -0.200
#
# EPOCH = 4, loss = 2.242,auc  = -0.200, val_loss = 1.500, val_auc = 0.077
#
# ================================================================================2021-10-06 10:18:37
# [step = 50] loss: 2.340, auc: -0.219
# [step = 100] loss: 2.229, auc: -0.197
#
# EPOCH = 5, loss = 2.229,auc  = -0.197, val_loss = 1.491, val_auc = 0.080
#
# ================================================================================2021-10-06 10:18:37
# [step = 50] loss: 2.328, auc: -0.217
# [step = 100] loss: 2.217, auc: -0.194
#
# EPOCH = 6, loss = 2.217,auc  = -0.194, val_loss = 1.483, val_auc = 0.083
#
# ================================================================================2021-10-06 10:18:37
# [step = 50] loss: 2.317, auc: -0.214
# [step = 100] loss: 2.207, auc: -0.192
#
# EPOCH = 7, loss = 2.207,auc  = -0.192, val_loss = 1.476, val_auc = 0.086
#
# ================================================================================2021-10-06 10:18:37
# [step = 50] loss: 2.308, auc: -0.213
# [step = 100] loss: 2.198, auc: -0.190
#
# EPOCH = 8, loss = 2.198,auc  = -0.190, val_loss = 1.470, val_auc = 0.088
#
# ================================================================================2021-10-06 10:18:37
# [step = 50] loss: 2.300, auc: -0.211
# [step = 100] loss: 2.189, auc: -0.188
#
# EPOCH = 9, loss = 2.189,auc  = -0.188, val_loss = 1.464, val_auc = 0.090
#
# ================================================================================2021-10-06 10:18:37
# [step = 50] loss: 2.292, auc: -0.210
# [step = 100] loss: 2.182, auc: -0.186
#
# EPOCH = 10, loss = 2.182,auc  = -0.186, val_loss = 1.460, val_auc = 0.092
#
# ================================================================================2021-10-06 10:18:37
# [step = 50] loss: 2.286, auc: -0.208
# [step = 100] loss: 2.175, auc: -0.184
#
# EPOCH = 11, loss = 2.175,auc  = -0.184, val_loss = 1.456, val_auc = 0.093
#
# ================================================================================2021-10-06 10:18:37
# [step = 50] loss: 2.279, auc: -0.207
# [step = 100] loss: 2.169, auc: -0.183
#
# EPOCH = 12, loss = 2.169,auc  = -0.183, val_loss = 1.452, val_auc = 0.095
#
# ================================================================================2021-10-06 10:18:37
# [step = 50] loss: 2.274, auc: -0.206
# [step = 100] loss: 2.164, auc: -0.181
#
# EPOCH = 13, loss = 2.164,auc  = -0.181, val_loss = 1.449, val_auc = 0.096
#
# ================================================================================2021-10-06 10:18:37
# [step = 50] loss: 2.269, auc: -0.205
# [step = 100] loss: 2.159, auc: -0.180
#
# EPOCH = 14, loss = 2.159,auc  = -0.180, val_loss = 1.446, val_auc = 0.098
#
# ================================================================================2021-10-06 10:18:37
# [step = 50] loss: 2.264, auc: -0.203
# [step = 100] loss: 2.154, auc: -0.179
#
# EPOCH = 15, loss = 2.154,auc  = -0.179, val_loss = 1.443, val_auc = 0.099
#
# ================================================================================2021-10-06 10:18:37
# [step = 50] loss: 2.260, auc: -0.202
# [step = 100] loss: 2.150, auc: -0.177
#
# EPOCH = 16, loss = 2.150,auc  = -0.177, val_loss = 1.441, val_auc = 0.100
#
# ================================================================================2021-10-06 10:18:37
# [step = 50] loss: 2.256, auc: -0.201
# [step = 100] loss: 2.146, auc: -0.176
#
# EPOCH = 17, loss = 2.146,auc  = -0.176, val_loss = 1.439, val_auc = 0.100
#
# ================================================================================2021-10-06 10:18:37
# [step = 50] loss: 2.252, auc: -0.200
# [step = 100] loss: 2.142, auc: -0.175
#
# EPOCH = 18, loss = 2.142,auc  = -0.175, val_loss = 1.437, val_auc = 0.101
#
# ================================================================================2021-10-06 10:18:37
# [step = 50] loss: 2.249, auc: -0.199
# [step = 100] loss: 2.139, auc: -0.174
#
# EPOCH = 19, loss = 2.139,auc  = -0.174, val_loss = 1.435, val_auc = 0.102
#
# ================================================================================2021-10-06 10:18:37
# [step = 50] loss: 2.245, auc: -0.198
# [step = 100] loss: 2.135, auc: -0.173
#
# EPOCH = 20, loss = 2.135,auc  = -0.173, val_loss = 1.434, val_auc = 0.102
#
# ================================================================================2021-10-06 10:18:37
# [step = 50] loss: 2.242, auc: -0.198
# [step = 100] loss: 2.132, auc: -0.173
#
# EPOCH = 21, loss = 2.132,auc  = -0.173, val_loss = 1.432, val_auc = 0.103
#
# ================================================================================2021-10-06 10:18:37
# [step = 50] loss: 2.240, auc: -0.197
# [step = 100] loss: 2.130, auc: -0.172
#
# EPOCH = 22, loss = 2.130,auc  = -0.172, val_loss = 1.431, val_auc = 0.104
#
# ================================================================================2021-10-06 10:18:37
# [step = 50] loss: 2.237, auc: -0.196
# [step = 100] loss: 2.127, auc: -0.171
#
# EPOCH = 23, loss = 2.127,auc  = -0.171, val_loss = 1.430, val_auc = 0.104
#
# ================================================================================2021-10-06 10:18:37
# [step = 50] loss: 2.234, auc: -0.195
# [step = 100] loss: 2.125, auc: -0.170
#
# EPOCH = 24, loss = 2.125,auc  = -0.170, val_loss = 1.429, val_auc = 0.105
#
# ================================================================================2021-10-06 10:18:37
# [step = 50] loss: 2.232, auc: -0.194
# [step = 100] loss: 2.122, auc: -0.169
#
# EPOCH = 25, loss = 2.122,auc  = -0.169, val_loss = 1.428, val_auc = 0.105
#
# ================================================================================2021-10-06 10:18:37
# [step = 50] loss: 2.230, auc: -0.194
# [step = 100] loss: 2.120, auc: -0.169
#
# EPOCH = 26, loss = 2.120,auc  = -0.169, val_loss = 1.427, val_auc = 0.105
#
# ================================================================================2021-10-06 10:18:37
# [step = 50] loss: 2.228, auc: -0.193
# [step = 100] loss: 2.118, auc: -0.168
#
# EPOCH = 27, loss = 2.118,auc  = -0.168, val_loss = 1.426, val_auc = 0.106
#
# ================================================================================2021-10-06 10:18:37
# [step = 50] loss: 2.226, auc: -0.192
# [step = 100] loss: 2.116, auc: -0.168
#
# EPOCH = 28, loss = 2.116,auc  = -0.168, val_loss = 1.425, val_auc = 0.106
#
# ================================================================================2021-10-06 10:18:38
# [step = 50] loss: 2.224, auc: -0.192
# [step = 100] loss: 2.114, auc: -0.167
#
# EPOCH = 29, loss = 2.114,auc  = -0.167, val_loss = 1.425, val_auc = 0.107
#
# ================================================================================2021-10-06 10:18:38
# [step = 50] loss: 2.222, auc: -0.191
# [step = 100] loss: 2.112, auc: -0.166
#
# EPOCH = 30, loss = 2.112,auc  = -0.166, val_loss = 1.424, val_auc = 0.107
#
# ================================================================================2021-10-06 10:18:38
# [step = 50] loss: 2.220, auc: -0.191
# [step = 100] loss: 2.110, auc: -0.166
#
# EPOCH = 31, loss = 2.110,auc  = -0.166, val_loss = 1.423, val_auc = 0.107
#
# ================================================================================2021-10-06 10:18:38
# [step = 50] loss: 2.219, auc: -0.190
# [step = 100] loss: 2.109, auc: -0.165
#
# EPOCH = 32, loss = 2.109,auc  = -0.165, val_loss = 1.423, val_auc = 0.107
#
# ================================================================================2021-10-06 10:18:38
# [step = 50] loss: 2.217, auc: -0.189
# [step = 100] loss: 2.107, auc: -0.165
#
# EPOCH = 33, loss = 2.107,auc  = -0.165, val_loss = 1.422, val_auc = 0.108
#
# ================================================================================2021-10-06 10:18:38
# [step = 50] loss: 2.216, auc: -0.189
# [step = 100] loss: 2.106, auc: -0.164
#
# EPOCH = 34, loss = 2.106,auc  = -0.164, val_loss = 1.422, val_auc = 0.108
#
# ================================================================================2021-10-06 10:18:38
# [step = 50] loss: 2.214, auc: -0.188
# [step = 100] loss: 2.104, auc: -0.164
#
# EPOCH = 35, loss = 2.104,auc  = -0.164, val_loss = 1.421, val_auc = 0.108
#
# ================================================================================2021-10-06 10:18:38
# [step = 50] loss: 2.213, auc: -0.188
# [step = 100] loss: 2.103, auc: -0.163
#
# EPOCH = 36, loss = 2.103,auc  = -0.163, val_loss = 1.421, val_auc = 0.109
#
# ================================================================================2021-10-06 10:18:38
# [step = 50] loss: 2.211, auc: -0.188
# [step = 100] loss: 2.101, auc: -0.163
#
# EPOCH = 37, loss = 2.101,auc  = -0.163, val_loss = 1.420, val_auc = 0.109
#
# ================================================================================2021-10-06 10:18:38
# [step = 50] loss: 2.210, auc: -0.187
# [step = 100] loss: 2.100, auc: -0.162
#
# EPOCH = 38, loss = 2.100,auc  = -0.162, val_loss = 1.420, val_auc = 0.109
#
# ================================================================================2021-10-06 10:18:38
# [step = 50] loss: 2.209, auc: -0.187
# [step = 100] loss: 2.099, auc: -0.162
#
# EPOCH = 39, loss = 2.099,auc  = -0.162, val_loss = 1.420, val_auc = 0.109
#
# ================================================================================2021-10-06 10:18:38
# [step = 50] loss: 2.207, auc: -0.186
# [step = 100] loss: 2.098, auc: -0.162
#
# EPOCH = 40, loss = 2.098,auc  = -0.162, val_loss = 1.419, val_auc = 0.109
#
# ================================================================================2021-10-06 10:18:38
# [step = 50] loss: 2.206, auc: -0.186
# [step = 100] loss: 2.096, auc: -0.161
#
# EPOCH = 41, loss = 2.096,auc  = -0.161, val_loss = 1.419, val_auc = 0.109
#
# ================================================================================2021-10-06 10:18:38
# [step = 50] loss: 2.205, auc: -0.185
# [step = 100] loss: 2.095, auc: -0.161
#
# EPOCH = 42, loss = 2.095,auc  = -0.161, val_loss = 1.419, val_auc = 0.109
#
# ================================================================================2021-10-06 10:18:38
# [step = 50] loss: 2.204, auc: -0.185
# [step = 100] loss: 2.094, auc: -0.161
#
# EPOCH = 43, loss = 2.094,auc  = -0.161, val_loss = 1.419, val_auc = 0.110
#
# ================================================================================2021-10-06 10:18:38
# [step = 50] loss: 2.203, auc: -0.185
# [step = 100] loss: 2.093, auc: -0.160
#
# EPOCH = 44, loss = 2.093,auc  = -0.160, val_loss = 1.418, val_auc = 0.110
#
# ================================================================================2021-10-06 10:18:38
# [step = 50] loss: 2.202, auc: -0.184
# [step = 100] loss: 2.092, auc: -0.160
#
# EPOCH = 45, loss = 2.092,auc  = -0.160, val_loss = 1.418, val_auc = 0.110
#
# ================================================================================2021-10-06 10:18:38
# [step = 50] loss: 2.201, auc: -0.184
# [step = 100] loss: 2.091, auc: -0.159
#
# EPOCH = 46, loss = 2.091,auc  = -0.159, val_loss = 1.418, val_auc = 0.110
#
# ================================================================================2021-10-06 10:18:38
# [step = 50] loss: 2.200, auc: -0.184
# [step = 100] loss: 2.090, auc: -0.159
#
# EPOCH = 47, loss = 2.090,auc  = -0.159, val_loss = 1.418, val_auc = 0.110
#
# ================================================================================2021-10-06 10:18:38
# [step = 50] loss: 2.199, auc: -0.183
# [step = 100] loss: 2.089, auc: -0.159
#
# EPOCH = 48, loss = 2.089,auc  = -0.159, val_loss = 1.417, val_auc = 0.110
#
# ================================================================================2021-10-06 10:18:38
# [step = 50] loss: 2.198, auc: -0.183
# [step = 100] loss: 2.088, auc: -0.159
#
# EPOCH = 49, loss = 2.088,auc  = -0.159, val_loss = 1.417, val_auc = 0.110
#
# ================================================================================2021-10-06 10:18:38
# [step = 50] loss: 2.197, auc: -0.183
# [step = 100] loss: 2.087, auc: -0.158
#
# EPOCH = 50, loss = 2.087,auc  = -0.158, val_loss = 1.417, val_auc = 0.110
#
# ================================================================================2021-10-06 10:18:38
# [step = 50] loss: 2.196, auc: -0.182
# [step = 100] loss: 2.086, auc: -0.158
#
# EPOCH = 51, loss = 2.086,auc  = -0.158, val_loss = 1.417, val_auc = 0.110
#
# ================================================================================2021-10-06 10:18:38
# [step = 50] loss: 2.195, auc: -0.182
# [step = 100] loss: 2.085, auc: -0.158
#
# EPOCH = 52, loss = 2.085,auc  = -0.158, val_loss = 1.417, val_auc = 0.111
#
# ================================================================================2021-10-06 10:18:38
# [step = 50] loss: 2.194, auc: -0.182
# [step = 100] loss: 2.084, auc: -0.157
#
# EPOCH = 53, loss = 2.084,auc  = -0.157, val_loss = 1.417, val_auc = 0.111
#
# ================================================================================2021-10-06 10:18:38
# [step = 50] loss: 2.193, auc: -0.182
# [step = 100] loss: 2.083, auc: -0.157
#
# EPOCH = 54, loss = 2.083,auc  = -0.157, val_loss = 1.416, val_auc = 0.111
#
# ================================================================================2021-10-06 10:18:38
# [step = 50] loss: 2.192, auc: -0.181
# [step = 100] loss: 2.082, auc: -0.157
#
# EPOCH = 55, loss = 2.082,auc  = -0.157, val_loss = 1.416, val_auc = 0.111
#
# ================================================================================2021-10-06 10:18:38
# [step = 50] loss: 2.191, auc: -0.181
# [step = 100] loss: 2.081, auc: -0.157
#
# EPOCH = 56, loss = 2.081,auc  = -0.157, val_loss = 1.416, val_auc = 0.111
#
# ================================================================================2021-10-06 10:18:38
# [step = 50] loss: 2.190, auc: -0.181
# [step = 100] loss: 2.080, auc: -0.156
#
# EPOCH = 57, loss = 2.080,auc  = -0.156, val_loss = 1.416, val_auc = 0.111
#
# ================================================================================2021-10-06 10:18:38
# [step = 50] loss: 2.189, auc: -0.180
# [step = 100] loss: 2.079, auc: -0.156
#
# EPOCH = 58, loss = 2.079,auc  = -0.156, val_loss = 1.416, val_auc = 0.111
#
# ================================================================================2021-10-06 10:18:38
# [step = 50] loss: 2.188, auc: -0.180
# [step = 100] loss: 2.079, auc: -0.156
#
# EPOCH = 59, loss = 2.079,auc  = -0.156, val_loss = 1.416, val_auc = 0.111
#
# ================================================================================2021-10-06 10:18:38
# [step = 50] loss: 2.187, auc: -0.180
# [step = 100] loss: 2.078, auc: -0.156
#
# EPOCH = 60, loss = 2.078,auc  = -0.156, val_loss = 1.416, val_auc = 0.111
#
# ================================================================================2021-10-06 10:18:38
# [step = 50] loss: 2.187, auc: -0.180
# [step = 100] loss: 2.077, auc: -0.155
#
# EPOCH = 61, loss = 2.077,auc  = -0.155, val_loss = 1.416, val_auc = 0.111
#
# ================================================================================2021-10-06 10:18:39
# [step = 50] loss: 2.186, auc: -0.179
# [step = 100] loss: 2.076, auc: -0.155
#
# EPOCH = 62, loss = 2.076,auc  = -0.155, val_loss = 1.416, val_auc = 0.111
#
# ================================================================================2021-10-06 10:18:39
# [step = 50] loss: 2.185, auc: -0.179
# [step = 100] loss: 2.075, auc: -0.155
#
# EPOCH = 63, loss = 2.075,auc  = -0.155, val_loss = 1.415, val_auc = 0.111
#
# ================================================================================2021-10-06 10:18:39
# [step = 50] loss: 2.184, auc: -0.179
# [step = 100] loss: 2.074, auc: -0.155
#
# EPOCH = 64, loss = 2.074,auc  = -0.155, val_loss = 1.415, val_auc = 0.111
#
# ================================================================================2021-10-06 10:18:39
# [step = 50] loss: 2.183, auc: -0.179
# [step = 100] loss: 2.074, auc: -0.154
#
# EPOCH = 65, loss = 2.074,auc  = -0.154, val_loss = 1.415, val_auc = 0.111
#
# ================================================================================2021-10-06 10:18:39
# [step = 50] loss: 2.182, auc: -0.178
# [step = 100] loss: 2.073, auc: -0.154
#
# EPOCH = 66, loss = 2.073,auc  = -0.154, val_loss = 1.415, val_auc = 0.111
#
# ================================================================================2021-10-06 10:18:39
# [step = 50] loss: 2.182, auc: -0.178
# [step = 100] loss: 2.072, auc: -0.154
#
# EPOCH = 67, loss = 2.072,auc  = -0.154, val_loss = 1.415, val_auc = 0.111
#
# ================================================================================2021-10-06 10:18:39
# [step = 50] loss: 2.181, auc: -0.178
# [step = 100] loss: 2.071, auc: -0.154
#
# EPOCH = 68, loss = 2.071,auc  = -0.154, val_loss = 1.415, val_auc = 0.112
#
# ================================================================================2021-10-06 10:18:39
# [step = 50] loss: 2.180, auc: -0.178
# [step = 100] loss: 2.070, auc: -0.153
#
# EPOCH = 69, loss = 2.070,auc  = -0.153, val_loss = 1.415, val_auc = 0.112
#
# ================================================================================2021-10-06 10:18:39
# [step = 50] loss: 2.179, auc: -0.178
# [step = 100] loss: 2.070, auc: -0.153
#
# EPOCH = 70, loss = 2.070,auc  = -0.153, val_loss = 1.415, val_auc = 0.112
#
# ================================================================================2021-10-06 10:18:39
# [step = 50] loss: 2.179, auc: -0.177
# [step = 100] loss: 2.069, auc: -0.153
#
# EPOCH = 71, loss = 2.069,auc  = -0.153, val_loss = 1.415, val_auc = 0.112
#
# ================================================================================2021-10-06 10:18:39
# [step = 50] loss: 2.178, auc: -0.177
# [step = 100] loss: 2.068, auc: -0.153
#
# EPOCH = 72, loss = 2.068,auc  = -0.153, val_loss = 1.415, val_auc = 0.112
#
# ================================================================================2021-10-06 10:18:39
# [step = 50] loss: 2.177, auc: -0.177
# [step = 100] loss: 2.067, auc: -0.153
#
# EPOCH = 73, loss = 2.067,auc  = -0.153, val_loss = 1.415, val_auc = 0.112
#
# ================================================================================2021-10-06 10:18:39
# [step = 50] loss: 2.176, auc: -0.177
# [step = 100] loss: 2.067, auc: -0.152
#
# EPOCH = 74, loss = 2.067,auc  = -0.152, val_loss = 1.415, val_auc = 0.112
#
# ================================================================================2021-10-06 10:18:39
# [step = 50] loss: 2.175, auc: -0.176
# [step = 100] loss: 2.066, auc: -0.152
#
# EPOCH = 75, loss = 2.066,auc  = -0.152, val_loss = 1.415, val_auc = 0.112
#
# ================================================================================2021-10-06 10:18:39
# [step = 50] loss: 2.175, auc: -0.176
# [step = 100] loss: 2.065, auc: -0.152
#
# EPOCH = 76, loss = 2.065,auc  = -0.152, val_loss = 1.415, val_auc = 0.112
#
# ================================================================================2021-10-06 10:18:39
# [step = 50] loss: 2.174, auc: -0.176
# [step = 100] loss: 2.065, auc: -0.152
#
# EPOCH = 77, loss = 2.065,auc  = -0.152, val_loss = 1.415, val_auc = 0.112
#
# ================================================================================2021-10-06 10:18:39
# [step = 50] loss: 2.173, auc: -0.176
# [step = 100] loss: 2.064, auc: -0.152
#
# EPOCH = 78, loss = 2.064,auc  = -0.152, val_loss = 1.415, val_auc = 0.112
#
# ================================================================================2021-10-06 10:18:39
# [step = 50] loss: 2.173, auc: -0.176
# [step = 100] loss: 2.063, auc: -0.151
#
# EPOCH = 79, loss = 2.063,auc  = -0.151, val_loss = 1.415, val_auc = 0.112
#
# ================================================================================2021-10-06 10:18:39
# [step = 50] loss: 2.172, auc: -0.175
# [step = 100] loss: 2.062, auc: -0.151
#
# EPOCH = 80, loss = 2.062,auc  = -0.151, val_loss = 1.415, val_auc = 0.112
#
# ================================================================================2021-10-06 10:18:39
# [step = 50] loss: 2.171, auc: -0.175
# [step = 100] loss: 2.062, auc: -0.151
#
# EPOCH = 81, loss = 2.062,auc  = -0.151, val_loss = 1.415, val_auc = 0.112
#
# ================================================================================2021-10-06 10:18:39
# [step = 50] loss: 2.170, auc: -0.175
# [step = 100] loss: 2.061, auc: -0.151
#
# EPOCH = 82, loss = 2.061,auc  = -0.151, val_loss = 1.415, val_auc = 0.112
#
# ================================================================================2021-10-06 10:18:39
# [step = 50] loss: 2.170, auc: -0.175
# [step = 100] loss: 2.060, auc: -0.151
#
# EPOCH = 83, loss = 2.060,auc  = -0.151, val_loss = 1.414, val_auc = 0.112
#
# ================================================================================2021-10-06 10:18:39
# [step = 50] loss: 2.169, auc: -0.175
# [step = 100] loss: 2.060, auc: -0.150
#
# EPOCH = 84, loss = 2.060,auc  = -0.150, val_loss = 1.414, val_auc = 0.112
#
# ================================================================================2021-10-06 10:18:39
# [step = 50] loss: 2.168, auc: -0.174
# [step = 100] loss: 2.059, auc: -0.150
#
# EPOCH = 85, loss = 2.059,auc  = -0.150, val_loss = 1.414, val_auc = 0.112
#
# ================================================================================2021-10-06 10:18:39
# [step = 50] loss: 2.167, auc: -0.174
# [step = 100] loss: 2.058, auc: -0.150
#
# EPOCH = 86, loss = 2.058,auc  = -0.150, val_loss = 1.414, val_auc = 0.112
#
# ================================================================================2021-10-06 10:18:39
# [step = 50] loss: 2.167, auc: -0.174
# [step = 100] loss: 2.057, auc: -0.150
#
# EPOCH = 87, loss = 2.057,auc  = -0.150, val_loss = 1.414, val_auc = 0.112
#
# ================================================================================2021-10-06 10:18:39
# [step = 50] loss: 2.166, auc: -0.174
# [step = 100] loss: 2.057, auc: -0.150
#
# EPOCH = 88, loss = 2.057,auc  = -0.150, val_loss = 1.414, val_auc = 0.112
#
# ================================================================================2021-10-06 10:18:39
# [step = 50] loss: 2.165, auc: -0.174
# [step = 100] loss: 2.056, auc: -0.149
#
# EPOCH = 89, loss = 2.056,auc  = -0.149, val_loss = 1.414, val_auc = 0.112
#
# ================================================================================2021-10-06 10:18:39
# [step = 50] loss: 2.165, auc: -0.174
# [step = 100] loss: 2.055, auc: -0.149
#
# EPOCH = 90, loss = 2.055,auc  = -0.149, val_loss = 1.414, val_auc = 0.112
#
# ================================================================================2021-10-06 10:18:39
# [step = 50] loss: 2.164, auc: -0.173
# [step = 100] loss: 2.055, auc: -0.149
#
# EPOCH = 91, loss = 2.055,auc  = -0.149, val_loss = 1.414, val_auc = 0.112
#
# ================================================================================2021-10-06 10:18:39
# [step = 50] loss: 2.163, auc: -0.173
# [step = 100] loss: 2.054, auc: -0.149
#
# EPOCH = 92, loss = 2.054,auc  = -0.149, val_loss = 1.414, val_auc = 0.112
#
# ================================================================================2021-10-06 10:18:39
# [step = 50] loss: 2.163, auc: -0.173
# [step = 100] loss: 2.053, auc: -0.149
#
# EPOCH = 93, loss = 2.053,auc  = -0.149, val_loss = 1.414, val_auc = 0.112
#
# ================================================================================2021-10-06 10:18:39
# [step = 50] loss: 2.162, auc: -0.173
# [step = 100] loss: 2.053, auc: -0.149
#
# EPOCH = 94, loss = 2.053,auc  = -0.149, val_loss = 1.414, val_auc = 0.112
#
# ================================================================================2021-10-06 10:18:39
# [step = 50] loss: 2.161, auc: -0.173
# [step = 100] loss: 2.052, auc: -0.148
#
# EPOCH = 95, loss = 2.052,auc  = -0.148, val_loss = 1.414, val_auc = 0.113
#
# ================================================================================2021-10-06 10:18:40
# [step = 50] loss: 2.160, auc: -0.173
# [step = 100] loss: 2.051, auc: -0.148
#
# EPOCH = 96, loss = 2.051,auc  = -0.148, val_loss = 1.414, val_auc = 0.113
#
# ================================================================================2021-10-06 10:18:40
# [step = 50] loss: 2.160, auc: -0.172
# [step = 100] loss: 2.051, auc: -0.148
#
# EPOCH = 97, loss = 2.051,auc  = -0.148, val_loss = 1.414, val_auc = 0.113
#
# ================================================================================2021-10-06 10:18:40
# [step = 50] loss: 2.159, auc: -0.172
# [step = 100] loss: 2.050, auc: -0.148
#
# EPOCH = 98, loss = 2.050,auc  = -0.148, val_loss = 1.414, val_auc = 0.113
#
# ================================================================================2021-10-06 10:18:40
# [step = 50] loss: 2.158, auc: -0.172
# [step = 100] loss: 2.049, auc: -0.148
#
# EPOCH = 99, loss = 2.049,auc  = -0.148, val_loss = 1.414, val_auc = 0.113
#
# ================================================================================2021-10-06 10:18:40
# [step = 50] loss: 2.158, auc: -0.172
# [step = 100] loss: 2.049, auc: -0.148
#
# EPOCH = 100, loss = 2.049,auc  = -0.148, val_loss = 1.414, val_auc = 0.113
#
# ================================================================================2021-10-06 10:18:40
# Finished Training...

# %%
history
# Out:
#    EPOCH       loss       auc  val_loss   val_auc
# 0      1  15.207211 -1.373539  1.537990  0.062256
# 1      2   2.274932 -0.207974  1.523182  0.067548
# 2      3   2.257295 -0.203666  1.510666  0.072541
# 3      4   2.242060 -0.200017  1.499946  0.076870
# 4      5   2.228789 -0.196763  1.490718  0.080427
# ..   ...        ...       ...       ...       ...
# 95    96   2.051395 -0.148192  1.414417  0.112534
# 96    97   2.050735 -0.148021  1.414423  0.112554
# 97    98   2.050079 -0.147850  1.414432  0.112565
# 98    99   2.049424 -0.147680  1.414441  0.112576
# 99   100   2.048772 -0.147511  1.414452  0.112587
#
# [100 rows x 5 columns]

# %%
# 测试model效果
features_test,labels_test = next(iter(dl_valid))
# labels = labels.reshape(8,1)
predictions_test = model(features_test)

# %%
predictions_test
# Out:
# tensor([[11.8668],
#         [12.2453],
#         [12.1601],
#         [12.2160],
#         [11.9624],
#         [11.9592],
#         [12.1191],
#         [11.9097]], grad_fn=<LeakyReluBackward0>)

# %%
labels_test
# Out:
# tensor([[12.9806],
#         [13.6311],
#         [10.5856],
#         [11.0930],
#         [10.9182],
#         [10.0491],
#         [12.1610],
#         [10.0896]])
